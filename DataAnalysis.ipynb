# %% [markdown]
# # 1) Data and package Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Fairmatic
# Out:
# /content/drive/My Drive/Fairmatic

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data.xlsx', sheet_name='Raw Data')
df.head()
# Out:
#   Opportunity Name     Stage Submission Received Date Quote Sent Date  \
# 0    Opportunity 1  Declined                 1/1/2023             NaN
# 1    Opportunity 2  Declined                 1/1/2023             NaN
# 2    Opportunity 3  Declined                1/10/2023             NaN
# 3    Opportunity 4  Declined                1/10/2023             NaN
# 4    Opportunity 5  Declined                1/10/2023             NaN
#
#   Close Date  Annual Premium Model Segment Declined Reason Lost Reason  \
# 0   4/1/2023         50000.0    Mid-Market  Business Class         NaN
# 1   4/1/2023        122500.0    Mid-Market  Vehicle weight         NaN
# 2  2/15/2023         24500.0    Mid-Market           Other         NaN
# 3  2/10/2023         50000.0          NEMT  Business Class         NaN
# 4  1/23/2023         80500.0    Mid-Market  Business Class         NaN
#
#                                Declined Other Reason Lost Other Reason
# 0  Declined due to operations not being an artisa...               NaN
# 1             heavy vehicles and ineligible trailers               NaN
# 2  Only 7 units on schedule, our min for this seg...               NaN
# 3  Level of patient care provided. In addition, t...               NaN
# 4  Not an Artisan class of business. (Storage & M...               NaN

# %%
df['Annual Premium(Thousands)'] = df['Annual Premium']/10000

# %% [markdown]
# # 2) Data Inspection

# %% [markdown]
# ## a) Data Summary

# %%
df.groupby('Stage').agg({'Opportunity Name':'count','Annual Premium(Thousands)':'sum'}).sort_values(by='Opportunity Name', ascending=False)
# Out:
#                      Opportunity Name  Annual Premium(Thousands)
# Stage
# Declined                         4780               59211.612647
# Lost                             1002               15504.803693
# Won                               184                3636.429154
# Quote Sent                         29                 275.527140
# Indication Sent                     7                  45.200000
# Opportunity Created                 1                   7.500000

# %%
df.groupby('Declined Reason').agg({'Opportunity Name':'count', 'Annual Premium(Thousands)':'sum'}).sort_values(by='Opportunity Name', ascending=False)
# Out:
#                                                     Opportunity Name  \
# Declined Reason
# Business Class                                                  1337
# Other                                                            962
# Operating state                                                  472
# Unresponsive Broker                                              435
# Fleet size below min unit count                                  318
# ...                                                              ...
# Operating state; Pricing not competitive; Other                    1
# Business Class; Operating state; Vehicle type; ...                 1
# Operating state; Insufficient Lead Time                            1
# Business Class; Operating state; Vehicle weight                    1
# Vehicle weight; Vehicle age; Other                                 1
#
#                                                     Annual Premium(Thousands)
# Declined Reason
# Business Class                                                   17155.707300
# Other                                                            11885.200778
# Operating state                                                   6617.134400
# Unresponsive Broker                                               3957.240545
# Fleet size below min unit count                                    329.484100
# ...                                                                       ...
# Operating state; Pricing not competitive; Other                     15.000000
# Business Class; Operating state; Vehicle type; ...                  15.400000
# Operating state; Insufficient Lead Time                            294.700000
# Business Class; Operating state; Vehicle weight                      3.500000
# Vehicle weight; Vehicle age; Other                                   4.800000
#
# [122 rows x 2 columns]

# %%
df.groupby('Declined Other Reason').agg({'Opportunity Name':'count', 'Annual Premium(Thousands)':'sum'}).sort_values(by='Opportunity Name', ascending=False)
# Out:
#                                                     Opportunity Name  \
# Declined Other Reason
# It was in stale state, before V1.0 Powertrain. ...                66
# Amazon DSP - past effective date / no admitted ...                61
# Amazon DSP                                                        44
# FL                                                                33
# GC                                                                15
# ...                                                              ...
# Declined due to operations of Portable Toilet R...                 1
# Declined due to operations not falling under an...                 1
# Declined due to operations not being an artisan...                 1
# Declined due to operations not being an artisan...                 1
# wrong email filled by the broker - unable to co...                 1
#
#                                                     Annual Premium(Thousands)
# Declined Other Reason
# It was in stale state, before V1.0 Powertrain. ...                  972.25475
# Amazon DSP - past effective date / no admitted ...                  810.25000
# Amazon DSP                                                          606.65000
# FL                                                                  643.51700
# GC                                                                  152.69360
# ...                                                                       ...
# Declined due to operations of Portable Toilet R...                    6.65000
# Declined due to operations not falling under an...                    5.00000
# Declined due to operations not being an artisan...                    5.00000
# Declined due to operations not being an artisan...                    5.00000
# wrong email filled by the broker - unable to co...                    6.90000
#
# [1976 rows x 2 columns]

# %% [markdown]
# ## b) Data Cleaning

# %% [markdown]
# + Check duplicated data
# + Check null data
# + Check inconsistencies data
# + Check

# %% [markdown]
# #### i) Check duplicate

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Opportunity Name, Stage, Submission Received Date, Quote Sent Date, Close Date, Annual Premium, Model Segment, Declined Reason, Lost Reason, Declined Other Reason, Lost Other Reason, Annual Premium(Thousands)]
# Index: []

# %% [markdown]
# No duplication

# %% [markdown]
# #### ii) Check null

# %%
null_percent = (df.isnull().sum() / len(df)) * 100
print(null_percent)
# Out:
# Opportunity Name              0.000000
# Stage                         0.000000
# Submission Received Date      0.000000
# Quote Sent Date              79.493587
# Close Date                    0.000000
# Annual Premium                0.000000
# Model Segment                 0.000000
# Declined Reason              17.091454
# Lost Reason                  82.608696
# Declined Other Reason        56.605031
# Lost Other Reason            92.786940
# Annual Premium(Thousands)     0.000000
# dtype: float64

# %% [markdown]
# <u>Hypothesis I:</u>
#
# Quote sent ~79% --> approximate 21% sub-to-quote ratio
#
# Declined 17% --> 83 % to quote != 79 % --> need to investigate on overlapped
# data or data inconsistencies (conflicting but may have some submission not being declined but still not being able to turn to quote ?)
#
# <u>Hypothesis II:</u>
#
# Lost ~ 18% of all submission + 17% of non-declined --> won ~ -1 % --> Data inconsistencies exists

# %% [markdown]
# #### iii) Data Inconsistencies

# %% [markdown]
# #### Date inconsistencies

# %%
#change datetime column
df['Submission Received Date'] = pd.to_datetime(df['Submission Received Date'])
df['Quote Sent Date'] = pd.to_datetime(df['Quote Sent Date'])
df['Close Date'] = pd.to_datetime(df['Close Date'])

df[['Submission Received Date', 'Quote Sent Date','Close Date']].dtypes
# Out:
# Submission Received Date    datetime64[ns]
# Quote Sent Date             datetime64[ns]
# Close Date                  datetime64[ns]
# dtype: object

# %%
df[(df['Submission Received Date'] > df['Quote Sent Date'])]
# Out:
#       Opportunity Name       Stage Submission Received Date Quote Sent Date  \
# 889    Opportunity 890         Won               2023-10-19      2023-09-21
# 1887  Opportunity 1888  Quote Sent               2023-12-13      2023-09-14
# 2014  Opportunity 2015    Declined               2023-12-19      2023-07-12
# 5661  Opportunity 5662         Won               2023-09-18      2023-09-01
# 5896  Opportunity 5897         Won               2023-09-29      2023-09-28
#
#      Close Date  Annual Premium Model Segment          Declined Reason  \
# 889  2023-10-19       149125.94     Last Mile                      NaN
# 1887 2023-10-01        90636.70     Last Mile                      NaN
# 2014 2024-01-31       100000.00    Mid-Market  Pricing not competitive
# 5661 2023-09-11       494342.00    Mid-Market                      NaN
# 5896 2023-09-29       120000.00           TNC                      NaN
#
#      Lost Reason Declined Other Reason  \
# 889          NaN                   NaN
# 1887         NaN                   NaN
# 2014       Other                   NaN
# 5661         NaN                   NaN
# 5896         NaN                   NaN
#
#                                       Lost Other Reason  \
# 889                                                 NaN
# 1887                                                NaN
# 2014  It was in stale state, before V1.0 Powertrain....
# 5661                                                NaN
# 5896                                                NaN
#
#       Annual Premium(Thousands)
# 889                   14.912594
# 1887                   9.063670
# 2014                  10.000000
# 5661                  49.434200
# 5896                  12.000000

# %%
# Extract correct data
df_quote = df[(df['Quote Sent Date'].notnull()) & (df['Submission Received Date'] < df['Quote Sent Date'])]

# Mean quote sent
df_quote['datediff'] = df_quote['Quote Sent Date'] - df_quote['Submission Received Date']
mean_quote_sent = df_quote['datediff'].mean()

# Replace data
mask = (df['Submission Received Date'] > df['Quote Sent Date'])
df.loc[mask, 'Quote Sent Date'] = df.loc[mask, 'Submission Received Date'] + mean_quote_sent
df.loc[mask, 'Quote Sent Date'] = df.loc[mask, 'Quote Sent Date'].dt.strftime('%Y-%m-%d')

# Display
df[mask]
# Out:
# <ipython-input-68-d1c2366ecd0d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_quote['datediff'] = df_quote['Quote Sent Date'] - df_quote['Submission Received Date']
#       Opportunity Name       Stage Submission Received Date Quote Sent Date  \
# 889    Opportunity 890         Won               2023-10-19      2023-11-07
# 1887  Opportunity 1888  Quote Sent               2023-12-13      2024-01-01
# 2014  Opportunity 2015    Declined               2023-12-19      2024-01-07
# 5661  Opportunity 5662         Won               2023-09-18      2023-10-07
# 5896  Opportunity 5897         Won               2023-09-29      2023-10-18
#
#      Close Date  Annual Premium Model Segment          Declined Reason  \
# 889  2023-10-19       149125.94     Last Mile                      NaN
# 1887 2023-10-01        90636.70     Last Mile                      NaN
# 2014 2024-01-31       100000.00    Mid-Market  Pricing not competitive
# 5661 2023-09-11       494342.00    Mid-Market                      NaN
# 5896 2023-09-29       120000.00           TNC                      NaN
#
#      Lost Reason Declined Other Reason  \
# 889          NaN                   NaN
# 1887         NaN                   NaN
# 2014       Other                   NaN
# 5661         NaN                   NaN
# 5896         NaN                   NaN
#
#                                       Lost Other Reason  \
# 889                                                 NaN
# 1887                                                NaN
# 2014  It was in stale state, before V1.0 Powertrain....
# 5661                                                NaN
# 5896                                                NaN
#
#       Annual Premium(Thousands)
# 889                   14.912594
# 1887                   9.063670
# 2014                  10.000000
# 5661                  49.434200
# 5896                  12.000000

# %%
df[(df['Submission Received Date'] > df['Quote Sent Date'])]
# Out:
# Empty DataFrame
# Columns: [Opportunity Name, Stage, Submission Received Date, Quote Sent Date, Close Date, Annual Premium, Model Segment, Declined Reason, Lost Reason, Declined Other Reason, Lost Other Reason, Annual Premium(Thousands)]
# Index: []

# %% [markdown]
# Suppose the typical duration between receiving a submission and sending a quote is n days. We will replace all the correct data entries by adding n days to the corresponding "Submission Received Date" value.

# %% [markdown]
# We will do the same with incorrect closed date

# %%
df[df['Submission Received Date'] > df['Close Date']].head()
# Out:
#       Opportunity Name       Stage Submission Received Date Quote Sent Date  \
# 517    Opportunity 518    Declined               2024-01-30             NaT
# 987    Opportunity 988    Declined               2023-10-24             NaT
# 1887  Opportunity 1888  Quote Sent               2023-12-13      2024-01-01
# 1995  Opportunity 1996    Declined               2023-12-18             NaT
# 2614  Opportunity 2615    Declined               2024-02-19             NaT
#
#      Close Date  Annual Premium Model Segment  \
# 517  2024-01-02          3500.0     Last Mile
# 987  2023-10-21         59500.0    Mid-Market
# 1887 2023-10-01         90636.7     Last Mile
# 1995 2023-12-08         49000.0    Mid-Market
# 2614 2024-02-07         36000.0    Mid-Market
#
#                                       Declined Reason Lost Reason  \
# 517   Business Class; Fleet size below min unit count         NaN
# 987   Business Class; Fleet size below min unit count         NaN
# 1887                                              NaN         NaN
# 1995                          Pricing not competitive         NaN
# 2614                           Insufficient Lead Time         NaN
#
#      Declined Other Reason Lost Other Reason  Annual Premium(Thousands)
# 517                    NaN               NaN                    0.35000
# 987                    NaN               NaN                    5.95000
# 1887                   NaN               NaN                    9.06367
# 1995                   NaN               NaN                    4.90000
# 2614                   NaN               NaN                    3.60000

# %%
# Extract correct data
df_close = df[(df['Close Date'].notnull()) & (df['Submission Received Date'] < df['Close Date'])]

# Mean close date
df_close['datediff'] = df_close['Close Date'] - df_close['Submission Received Date']
mean_close_date = df_quote['datediff'].mean().days

# Replace data
mask = (df['Submission Received Date'] > df['Close Date'])
df.loc[mask, 'Close Date'] = df.loc[mask, 'Submission Received Date'] + pd.Timedelta(days=mean_close_date)

# Modify "Submission Received Date" and "Close Date" columns to display year-month-day format
df['Submission Received Date'] = df['Submission Received Date'].dt.strftime('%Y-%m-%d')
df['Close Date'] = df['Close Date'].dt.strftime('%Y-%m-%d')
# Out:
# <ipython-input-71-c032c3429ef8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_close['datediff'] = df_close['Close Date'] - df_close['Submission Received Date']

# %%
df[df['Submission Received Date'] > df['Close Date']].head()
# Out:
# Empty DataFrame
# Columns: [Opportunity Name, Stage, Submission Received Date, Quote Sent Date, Close Date, Annual Premium, Model Segment, Declined Reason, Lost Reason, Declined Other Reason, Lost Other Reason, Annual Premium(Thousands)]
# Index: []

# %% [markdown]
# #### Fact Inconsistencies

# %%
df[(df['Stage']=='Declined') & (df['Quote Sent Date'].notnull())]
# Out:
#       Opportunity Name     Stage Submission Received Date Quote Sent Date  \
# 392    Opportunity 393  Declined               2024-01-25      2024-02-26
# 474    Opportunity 475  Declined               2023-01-03      2023-01-17
# 909    Opportunity 910  Declined               2022-10-20      2022-11-01
# 1639  Opportunity 1640  Declined               2022-11-03      2022-11-23
# 2014  Opportunity 2015  Declined               2023-12-19      2024-01-07
# 2055  Opportunity 2056  Declined               2022-12-20      2023-01-08
# 2206  Opportunity 2207  Declined               2022-12-29      2023-01-10
# 2274  Opportunity 2275  Declined               2022-12-06      2023-01-10
# 2399  Opportunity 2400  Declined               2022-12-09      2022-12-22
# 3298  Opportunity 3299  Declined               2023-03-21      2023-04-01
# 3598  Opportunity 3599  Declined               2023-04-12      2023-04-20
# 4137  Opportunity 4138  Declined               2023-05-04      2023-05-12
# 4388  Opportunity 4389  Declined               2023-06-25      2023-07-11
# 5567  Opportunity 5568  Declined               2022-09-13      2022-12-21
#
#       Close Date  Annual Premium Model Segment          Declined Reason  \
# 392   2024-03-08       820300.00          NEMT                    Other
# 474   2023-01-29        42000.00    Mid-Market  Pricing not competitive
# 909   2023-02-01        82156.00      Cannabis         Prior Submission
# 1639  2023-01-01       340108.95    Mid-Market      Unresponsive Broker
# 2014  2024-01-31       100000.00    Mid-Market  Pricing not competitive
# 2055  2023-01-31       150000.00    Mid-Market      Unresponsive Broker
# 2206  2023-01-29       100000.00           TNC      Unresponsive Broker
# 2274  2023-01-21       100000.00     Last Mile                    Other
# 2399  2023-01-15        11984.00    Mid-Market          Operating state
# 3298  2023-04-01       231000.00    Mid-Market          Operating state
# 3598  2023-04-27        67375.00    Mid-Market  Pricing not competitive
# 4137  2023-05-15        87500.00     Last Mile           Business Class
# 4388  2023-07-11        98000.00    Mid-Market           Business Class
# 5567  2023-01-01        87426.00    Mid-Market                    Other
#
#      Lost Reason                              Declined Other Reason  \
# 392          NaN                              BOR'd to other agent.
# 474          NaN                                                NaN
# 909          NaN                                                NaN
# 1639         NaN                                                NaN
# 2014       Other                                                NaN
# 2055         NaN                                                NaN
# 2206         NaN                                                NaN
# 2274         NaN                                         Amazon DSP
# 2399         NaN                                Operates in Florida
# 3298         NaN                                                 KS
# 3598         NaN                         Bound with another carrier
# 4137         NaN  biohazard exposure with transporting medical s...
# 4388         NaN                                     Not an artisan
# 5567         NaN            Stayed with current carrier (Travelers)
#
#                                       Lost Other Reason  \
# 392                                                 NaN
# 474                                                 NaN
# 909                                                 NaN
# 1639                                                NaN
# 2014  It was in stale state, before V1.0 Powertrain....
# 2055                                                NaN
# 2206                                                NaN
# 2274                                                NaN
# 2399                                                NaN
# 3298                                                NaN
# 3598                                                NaN
# 4137                                                NaN
# 4388                                                NaN
# 5567                                                NaN
#
#       Annual Premium(Thousands)
# 392                   82.030000
# 474                    4.200000
# 909                    8.215600
# 1639                  34.010895
# 2014                  10.000000
# 2055                  15.000000
# 2206                  10.000000
# 2274                  10.000000
# 2399                   1.198400
# 3298                  23.100000
# 3598                   6.737500
# 4137                   8.750000
# 4388                   9.800000
# 5567                   8.742600

# %% [markdown]
# Submission has been declined but still sent quote --> Decline after the quote being sent ?
#
# 1 lost reason (op 2015): machine not compatible
#
# Declined Reasons: Unresponsive workers, Pricing Not Competitive, Operating Sate, Business Class .

# %%
df[(df['Stage']=='Won') & (df['Lost Reason'].notnull())]
# Out:
#       Opportunity Name Stage Submission Received Date Quote Sent Date  \
# 1997  Opportunity 1998   Won               2022-12-19      2023-04-14
# 2804  Opportunity 2805   Won               2024-02-24      2024-03-13
# 4241  Opportunity 4242   Won               2023-06-13      2023-07-26
#
#       Close Date  Annual Premium Model Segment Declined Reason   Lost Reason  \
# 1997  2023-11-01        150000.0           TNC             NaN         Other
# 2804  2024-02-29         53046.0     Last Mile             NaN  Unresponsive
# 4241  2023-08-08         58710.0    Mid-Market             NaN         Other
#
#      Declined Other Reason                                  Lost Other Reason  \
# 1997                   NaN                                                NaN
# 2804                   NaN                       never heard back from broker
# 4241                   NaN  It was in stale state, before V1.0 Powertrain....
#
#       Annual Premium(Thousands)
# 1997                    15.0000
# 2804                     5.3046
# 4241                     5.8710

# %%
df[(df['Stage']=='Won') & (df['Lost Reason'].notnull())]['Stage'] = 'Lost'
# Out:
# <ipython-input-75-f4ea926854a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[(df['Stage']=='Won') & (df['Lost Reason'].notnull())]['Stage'] = 'Lost'

# %%
df[(df['Stage']=='Won') & (df['Lost Reason'].notnull())]
# Out:
#       Opportunity Name Stage Submission Received Date Quote Sent Date  \
# 1997  Opportunity 1998   Won               2022-12-19      2023-04-14
# 2804  Opportunity 2805   Won               2024-02-24      2024-03-13
# 4241  Opportunity 4242   Won               2023-06-13      2023-07-26
#
#       Close Date  Annual Premium Model Segment Declined Reason   Lost Reason  \
# 1997  2023-11-01        150000.0           TNC             NaN         Other
# 2804  2024-02-29         53046.0     Last Mile             NaN  Unresponsive
# 4241  2023-08-08         58710.0    Mid-Market             NaN         Other
#
#      Declined Other Reason                                  Lost Other Reason  \
# 1997                   NaN                                                NaN
# 2804                   NaN                       never heard back from broker
# 4241                   NaN  It was in stale state, before V1.0 Powertrain....
#
#       Annual Premium(Thousands)
# 1997                    15.0000
# 2804                     5.3046
# 4241                     5.8710

# %%
#Has been closed (final result is declined) but still being segmented as "Opportunity Created"
df.loc[(df['Stage']=='Opportunity Created')] = "Declined"

# %% [markdown]
# #### Data Incompleteness

# %%
df[df['Submission Received Date']=='Declined']
# Out:
#      Opportunity Name     Stage Submission Received Date Quote Sent Date  \
# 1973         Declined  Declined                 Declined        Declined
#
#      Close Date Annual Premium Model Segment Declined Reason Lost Reason  \
# 1973   Declined       Declined      Declined        Declined    Declined
#
#      Declined Other Reason Lost Other Reason Annual Premium(Thousands)
# 1973              Declined          Declined                  Declined

# %% [markdown]
# Invalid row --> drop row

# %%
df = df[df['Submission Received Date'] != 'Declined']

# %%
df['Submission Received Date'].sort_values(ascending=False).head(1)
# Out:
# 3672    2024-04-18
# Name: Submission Received Date, dtype: object

# %%
df['Close Date'] = pd.to_datetime(df['Close Date'])

df_sep = df[(df['Close Date'].dt.year == 2023) & (df['Close Date'].dt.month == 9)][['Declined Reason','Declined Other Reason']]

# %%
df_sep = df_sep[df_sep['Declined Reason'].notnull()]

# %%
df_sep['Declined Reason'].value_counts()
# Out:
# Declined Reason
# Business Class                                                                    114
# Other                                                                              85
# Fleet size below min unit count                                                    66
# Operating state                                                                    61
# Unresponsive Broker                                                                42
# Below Minimum Premium                                                              41
# Below Minimum Premium; Fleet size below min unit count                             13
# Vehicle weight                                                                     13
# Pricing not competitive                                                             8
# Business Class; Vehicle weight                                                      6
# Operating state; Other                                                              6
# Prior Submission                                                                    5
# Insufficient Lead Time                                                              4
# Refused to provide info                                                             4
# Vehicle age                                                                         4
# Technology issue                                                                    3
# Operating state; Fleet size below min unit count                                    3
# Vehicle type; Other                                                                 2
# Business Class; Below Minimum Premium                                               2
# Vehicle type                                                                        2
# Fleet size below min unit count; Other                                              2
# Business Class; Vehicle type                                                        2
# Business Class; Fleet size below min unit count                                     2
# Business Class; Vehicle age                                                         2
# Vehicle age; Other                                                                  2
# Drivers above 70                                                                    2
# Vehicle type; Vehicle weight                                                        2
# Business Class; Technology issue                                                    1
# Operating state; Below Minimum Premium                                              1
# Vehicle weight; Vehicle age                                                         1
# Insufficient Lead Time; Below Minimum Premium; Fleet size below min unit count      1
# Pricing not competitive; Other                                                      1
# Vehicle age; Pricing not competitive                                                1
# Business Class; Vehicle type; Vehicle weight                                        1
# Insufficient Lead Time; Other                                                       1
# Refused to provide info; Other                                                      1
# Business Class; Vehicle type; Vehicle age                                           1
# Name: count, dtype: int64

# %% [markdown]
# Only 2 submissions received in the most recent month

# %%
df['Submission Received Date'].sort_values(ascending=True).head(1)

# %%
df[(df['Submission Received Date'].dt.year == 2021)]

# %% [markdown]
# First opportunity received in the company

# %% [markdown]
# # 3) Decline Analysis

# %% [markdown]
# ### a) All declined reasons by quantity

# %%
df_declined = df.dropna(subset=["Declined Reason"])

# %%
filtered_df = df_declined[df_declined["Declined Reason"].str.contains("Business Class", case=False)]

num_rows = len(filtered_df)
num_rows = filtered_df.shape[0]

num_rows

# %%
df_declined['Declined Reason'] = df_declined['Declined Reason'].str.split("; ")

# %%
big_list = sum([sublist * len(sublist) for sublist in df_declined['Declined Reason']], [])

len(big_list)

# %%
declined_series = pd.Series(big_list)
declined_series = pd.Series(declined_series.value_counts())

declined_series.to_csv("declined.csv")

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.barplot(declined_series, ax=ax)

# Rotate the x-axis tick labels to vertical
plt.xticks(rotation=90)
plt.show()

# %%
declined_series

# %% [markdown]
# ### b) Declined Reasons specific by real-time analysis

# %%
#all the reasons for analyzing
reasons = ['Business Class', 'Other', 'Operating state', 'Vehicle weight', 'Unresponsive Broker', 'Fleet size below min unit count', 'Vehicle type', 'Pricing not competitive', 'Vehicle age', 'Prior Submission', 'Below Minimum Premium', 'Insufficient Lead Time', 'Loss ratio', 'Technology issue', 'Refused to provide info']

# Create a figure with 5 rows and 3 columns of subplots
fig, axes = plt.subplots(5, 3, figsize=(30, 20))

# Flatten the axes array to iterate over each subplot
axes = axes.flatten()

# Iterate over each reason and create a subplot
for i, reason in enumerate(reasons):
    bc_df = df_declined[df_declined['Declined Reason'].apply(lambda x: reason in x)]
    bc_df['Submission Received Date'] = pd.to_datetime(bc_df['Submission Received Date'])

    month_counts = bc_df.groupby([bc_df['Submission Received Date'].dt.year, bc_df['Submission Received Date'].dt.month]).size()

    # Sort the months in alphabetical order
    month_counts = month_counts.reindex(sorted(month_counts.index))

    # Create the bar plot in the current subplot
    month_counts.plot(kind='bar', ax=axes[i])
    axes[i].set_title(reason)
    axes[i].tick_params(axis='x', rotation=45)

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.5)

# Show the plot
plt.show()

# %% [markdown]
# Still increase dramatically in last year, but downward this year.

# %% [markdown]
# # 4) Date diff vs closed case

# %%
qs_df = df[df['Quote Sent Date'].notnull()]

qs_df['Submission Received Date'] = pd.to_datetime(qs_df['Submission Received Date'])
qs_df['Quote Sent Date'] = pd.to_datetime(qs_df['Quote Sent Date'])

# %%
qs_df['Date Process'] = qs_df['Quote Sent Date'] - qs_df['Submission Received Date']

qs_df.head()

# %%
print("Average Decline Time:")
print(qs_df[qs_df['Stage']=='Declined']['Date Process'].mean())
print("Average Quote Time:")
print(qs_df[qs_df['Stage']!='Declined']['Date Process'].mean())

# %%
df[df['Opportunity Name']=='Opportunity 11']

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Create the first boxplot for declined submissions
sns.boxplot(qs_df[qs_df['Stage']=='Declined']['Date Process'], ax=ax1)
ax1.set_title('Declined Submissions')
ax1.set_xlabel('Date Process')

# Create the second boxplot for non-declined submissions
sns.boxplot(qs_df[qs_df['Stage']!='Declined']['Date Process'], ax=ax2)
ax2.set_title('Non-Declined Submissions')
ax2.set_xlabel('Date Process')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.5)

# Show the plot
plt.show()

# %% [markdown]
# # 5) Declined by Other Reasons

# %% [markdown]
# ### a) Biagrams & Triagrams

# %%
import nltk
nltk.download('punkt')

from nltk import ngrams
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_declined_others = df_declined[df_declined['Declined Other Reason'].notnull()]

# %%
declined_other_reasons = df_declined_others['Declined Other Reason']

# %%
tokenized_reasons = [nltk.word_tokenize(reason) for reason in declined_other_reasons]

# List of words to exclude
words_to_exclude = ['due', 'to']

# Filter out the words to exclude from the tokenized text
filtered_reasons = [[word for word in tokens if word.lower() not in words_to_exclude] for tokens in tokenized_reasons]

# %%
bigrams = [list(ngrams(tokens, 2)) for tokens in filtered_reasons]
trigrams = [list(ngrams(tokens, 3)) for tokens in filtered_reasons]

# %%
from nltk import FreqDist

bigram_freq = FreqDist([gram for sublist in bigrams for gram in sublist])
trigram_freq = FreqDist([gram for sublist in trigrams for gram in sublist])

# %%
# Get the top 10 bigrams and trigrams
top_10_bigrams = bigram_freq.most_common(10)
top_10_trigrams = trigram_freq.most_common(10)

# Create Pandas DataFrames
bigram_df = pd.DataFrame(top_10_bigrams, columns=['Bigram', 'Frequency'])
trigram_df = pd.DataFrame(top_10_trigrams, columns=['Trigram', 'Frequency'])

# Display the DataFrames
print("Top 10 Bigrams:")
print(bigram_df)
print("\nTop 10 Trigrams:")
print(trigram_df)
# Out:
# Top 10 Bigrams:
#                  Bigram  Frequency
# 0         (Amazon, DSP)        186
# 1     (effective, date)        182
# 2  (admitted, solution)        133
# 3         (Closed, out)        126
# 4        (no, admitted)        115
# 5           (in, place)        113
# 6        (solution, in)        109
# 7     (past, effective)        104
# 8              (-, not)        104
# 9         (an, artisan)         98
#
# Top 10 Trigrams:
#                     Trigram  Frequency
# 0  (no, admitted, solution)        113
# 1  (admitted, solution, in)        109
# 2     (solution, in, place)        109
# 3   (past, effective, date)        104
# 4          (Amazon, DSP, -)         96
# 5      (-, past, effective)         89
# 6         (/, no, admitted)         86
# 7      (effective, date, /)         81
# 8             (date, /, no)         80
# 9            (DSP, -, past)         79

# %% [markdown]
# ### b) Top 10 frequency investiagting

# %%
df_declined = df.dropna(subset=["Declined Reason"])

# %%
df_declined[df_declined['Declined Reason'].str.contains("Amazon")]

# %%
df_declined
